# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import numpy as np

from warnings import filterwarnings
filterwarnings('ignore')

import os
os.chdir(r'D:\OneDrive\Documents\Course\Imarticus Learning\Tableau\Data')

# %%
people=pd.read_excel('RuralAtlasData24.xlsx', sheet_name='People')
people.head()
# Out:
#    FIPS State         County  Pop_change_Rate_2020_2021  POPESTIMATE2021  \
# 0     0    US  United States                   0.118451      331893745.0
# 1  1000    AL        Alabama                   0.299992        5039877.0
# 2  1001    AL        Autauga                   0.370263          59095.0
# 3  1003    AL        Baldwin                   2.639616         239294.0
# 4  1005    AL        Barbour                  -0.857824          24964.0
#
#    Net_Migration_Rate_2020_2021  Natural_Change_Rate_2020_2021  \
# 0                      0.073792                       0.044658
# 1                      0.470108                      -0.170116
# 2                      0.424614                      -0.054351
# 3                      2.899974                      -0.260359
# 4                     -0.381255                      -0.476569
#
#    Net_InterMigrationRate_2020_2021  PopChangeRate1020  PopDensity2020  ...  \
# ...

# %%
people.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3280 entries, 0 to 3279
# Data columns (total 94 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   FIPS                                        3280 non-null   int64
#  1   State                                       3280 non-null   object
#  2   County                                      3280 non-null   object
#  3   Pop_change_Rate_2020_2021                   3195 non-null   float64
#  4   POPESTIMATE2021                             3274 non-null   float64
#  5   Net_Migration_Rate_2020_2021                3195 non-null   float64
#  6   Natural_Change_Rate_2020_2021               3195 non-null   float64
#  7   Net_InterMigrationRate_2020_2021            3195 non-null   float64
#  8   PopChangeRate1020                           3271 non-null   float64
# ...

# %%
people.columns
# Out:
# Index(['FIPS', 'State', 'County', 'Pop_change_Rate_2020_2021',
#        'POPESTIMATE2021', 'Net_Migration_Rate_2020_2021',
#        'Natural_Change_Rate_2020_2021', 'Net_InterMigrationRate_2020_2021',
#        'PopChangeRate1020', 'PopDensity2020', 'Under18Pct2020',
#        'Age65AndOlderPct2020', 'WhiteNonHispanicPct2020',
#        'BlackNonHispanicPct2020', 'AsianNonHispanicPct2020',
#        'NativeAmericanNonHispanicPct2020', 'HispanicPct2020',
#        'MultipleRacePct2020', 'NonHispWhitePopChangeRate1020',
#        'NonHispBlackPopChangeRate1020', 'NonHispAsianPopChangeRate1020',
#        'NonHispNatAmerPopChangeRate1020', 'HispanicPopChangeRate1020',
#        'MultipleRacePopChangeRate1020', 'WhiteNonHispanicNum2020',
#        'BlackNonHispanicNum2020', 'AsianNonHispanicNum2020',
#        'NativeAmericanNonHispanicNum2020', 'HispanicNum2020',
#        'MultipleRaceNum2020', 'ForeignBornPct', 'ForeignBornEuropePct',
# ...

# %%
people.drop('FIPS', axis=1, inplace=True)
people.drop(0, inplace=True)
people.head()
# Out:
#   State   County  Pop_change_Rate_2020_2021  POPESTIMATE2021  \
# 1    AL  Alabama                   0.299992        5039877.0
# 2    AL  Autauga                   0.370263          59095.0
# 3    AL  Baldwin                   2.639616         239294.0
# 4    AL  Barbour                  -0.857824          24964.0
# 5    AL     Bibb                   1.142960          22477.0
#
#    Net_Migration_Rate_2020_2021  Natural_Change_Rate_2020_2021  \
# 1                      0.470108                      -0.170116
# 2                      0.424614                      -0.054351
# 3                      2.899974                      -0.260359
# 4                     -0.381255                      -0.476569
# 5                      1.394951                      -0.251991
#
#    Net_InterMigrationRate_2020_2021  PopChangeRate1020  PopDensity2020  \
# 1                          0.024757           5.116245       99.201651
# 2                          0.008492           7.758700       98.922358
# ...

# %%
people.isnull().sum()
# Out:
# State                            0
# County                           0
# Pop_change_Rate_2020_2021       85
# POPESTIMATE2021                  6
# Net_Migration_Rate_2020_2021    85
#                                 ..
# ESTIMATESBASE2020                6
# POPESTIMATE2020                  6
# NaturalChg2020_2021             85
# Net_InterMigration_2020_2021    85
# Net_Migration_2020_2021         85
# Length: 93, dtype: int64

# %%
people.columns
# Out:
# Index(['State', 'County', 'Pop_change_Rate_2020_2021', 'POPESTIMATE2021',
#        'Net_Migration_Rate_2020_2021', 'Natural_Change_Rate_2020_2021',
#        'Net_InterMigrationRate_2020_2021', 'PopChangeRate1020',
#        'PopDensity2020', 'Under18Pct2020', 'Age65AndOlderPct2020',
#        'WhiteNonHispanicPct2020', 'BlackNonHispanicPct2020',
#        'AsianNonHispanicPct2020', 'NativeAmericanNonHispanicPct2020',
#        'HispanicPct2020', 'MultipleRacePct2020',
#        'NonHispWhitePopChangeRate1020', 'NonHispBlackPopChangeRate1020',
#        'NonHispAsianPopChangeRate1020', 'NonHispNatAmerPopChangeRate1020',
#        'HispanicPopChangeRate1020', 'MultipleRacePopChangeRate1020',
#        'WhiteNonHispanicNum2020', 'BlackNonHispanicNum2020',
#        'AsianNonHispanicNum2020', 'NativeAmericanNonHispanicNum2020',
#        'HispanicNum2020', 'MultipleRaceNum2020', 'ForeignBornPct',
#        'ForeignBornEuropePct', 'ForeignBornMexPct', 'NonEnglishHHPct',
# ...

# %%
#Outlier
cols= ['Pop_change_Rate_2020_2021', 'POPESTIMATE2021',
       'Net_Migration_Rate_2020_2021', 'Natural_Change_Rate_2020_2021',
       'Net_InterMigrationRate_2020_2021', 'PopChangeRate1020',
       'PopDensity2020', 'Under18Pct2020', 'Age65AndOlderPct2020',
       'WhiteNonHispanicPct2020', 'BlackNonHispanicPct2020',
       'AsianNonHispanicPct2020', 'NativeAmericanNonHispanicPct2020',
       'HispanicPct2020', 'MultipleRacePct2020',
       'NonHispWhitePopChangeRate1020', 'NonHispBlackPopChangeRate1020',
       'NonHispAsianPopChangeRate1020', 'NonHispNatAmerPopChangeRate1020',
       'HispanicPopChangeRate1020', 'MultipleRacePopChangeRate1020',
       'WhiteNonHispanicNum2020', 'BlackNonHispanicNum2020',
       'AsianNonHispanicNum2020', 'NativeAmericanNonHispanicNum2020',
       'HispanicNum2020', 'MultipleRaceNum2020', 'ForeignBornPct',
       'ForeignBornEuropePct', 'ForeignBornMexPct', 'NonEnglishHHPct',
       'Ed1LessThanHSPct', 'Ed2HSDiplomaOnlyPct', 'Ed3SomeCollegePct',
       'Ed4AssocDegreePct', 'Ed5CollegePlusPct', 'AvgHHSize', 'FemaleHHPct',
       'HH65PlusAlonePct', 'OwnHomePct', 'Ed3SomeCollegeNum',
       'Ed2HSDiplomaOnlyNum', 'Ed1LessThanHSNum', 'TotalPopACS',
       'ForeignBornNum', 'TotalPop25Plus', 'ForeignBornEuropeNum',
       'ForeignBornCaribNum', 'ForeignBornMexNum', 'Ed5CollegePlusNum',
       'HH65PlusAloneNum', 'Ed4AssocDegreeNum', 'ForeignBornAfricaNum',
       'ForeignBornAsiaNum', 'NonEnglishHHNum', 'OwnHomeNum', 'FemaleHHNum',
       'TotalHH', 'ForeignBornCentralSouthAmPct',
       'ForeignBornCentralSouthAmNum', 'ForeignBornCaribPct',
       'ForeignBornAsiaPct', 'TotalOccHU', 'ForeignBornAfricaPct',
       'Age65AndOlderNum2020', 'Under18Num2020', 'LandAreaSQMiles2020',
       'TotalPop2020', 'NaturalChange1019', 'TotalPopEst2015',
       'TotalPopEst2016', 'TotalPopEst2017', 'TotalPopEst2018',
       'Net_International_Migration_2010_2019', 'TotalPopEst2019',
       'TotalPopEst2012', 'NetMigration1019',
       'Net_International_Migration_Rate_2010_2019', 'NaturalChangeRate1019',
       'NetMigrationRate1019', 'PopChangeRate1019', 'TotalPopEst2014',
       'TotalPopEst2013', 'TotalPopEstBase2010', 'TotalPopEst2011',
       'TotalPopEst2010', 'ESTIMATESBASE2020', 'POPESTIMATE2020',
       'NaturalChg2020_2021', 'Net_InterMigration_2020_2021',
       'Net_Migration_2020_2021']

fig, axes = plt.subplots(23,4, figsize=(50, 100)) 
axes = axes.flatten()  # Flatten the 2D array of axes for easier access

# Plotting each column
for i in range(len(cols)):
    sns.boxplot(data=people, y=cols[i], ax=axes[i])

plt.tight_layout()
plt.show()

# %%
#Identifying Outliers

cols=['Pop_change_Rate_2020_2021', 'POPESTIMATE2021',
       'Net_Migration_Rate_2020_2021', 'Natural_Change_Rate_2020_2021',
       'Net_InterMigrationRate_2020_2021', 'PopChangeRate1020',
       'PopDensity2020', 'Under18Pct2020', 'Age65AndOlderPct2020',
       'WhiteNonHispanicPct2020', 'BlackNonHispanicPct2020',
       'AsianNonHispanicPct2020', 'NativeAmericanNonHispanicPct2020',
       'HispanicPct2020', 'MultipleRacePct2020',
       'NonHispWhitePopChangeRate1020', 'NonHispBlackPopChangeRate1020',
       'NonHispAsianPopChangeRate1020', 'NonHispNatAmerPopChangeRate1020',
       'HispanicPopChangeRate1020', 'MultipleRacePopChangeRate1020',
       'WhiteNonHispanicNum2020', 'BlackNonHispanicNum2020',
       'AsianNonHispanicNum2020', 'NativeAmericanNonHispanicNum2020',
       'HispanicNum2020', 'MultipleRaceNum2020', 'ForeignBornPct',
       'ForeignBornEuropePct', 'ForeignBornMexPct', 'NonEnglishHHPct',
       'Ed1LessThanHSPct', 'Ed2HSDiplomaOnlyPct', 'Ed3SomeCollegePct',
       'Ed4AssocDegreePct', 'Ed5CollegePlusPct', 'AvgHHSize', 'FemaleHHPct',
       'HH65PlusAlonePct', 'OwnHomePct', 'Ed3SomeCollegeNum',
       'Ed2HSDiplomaOnlyNum', 'Ed1LessThanHSNum', 'TotalPopACS',
       'ForeignBornNum', 'TotalPop25Plus', 'ForeignBornEuropeNum',
       'ForeignBornCaribNum', 'ForeignBornMexNum', 'Ed5CollegePlusNum',
       'HH65PlusAloneNum', 'Ed4AssocDegreeNum', 'ForeignBornAfricaNum',
       'ForeignBornAsiaNum', 'NonEnglishHHNum', 'OwnHomeNum', 'FemaleHHNum',
       'TotalHH', 'ForeignBornCentralSouthAmPct',
       'ForeignBornCentralSouthAmNum', 'ForeignBornCaribPct',
       'ForeignBornAsiaPct', 'TotalOccHU', 'ForeignBornAfricaPct',
       'Age65AndOlderNum2020', 'Under18Num2020', 'LandAreaSQMiles2020',
       'TotalPop2020', 'NaturalChange1019', 'TotalPopEst2015',
       'TotalPopEst2016', 'TotalPopEst2017', 'TotalPopEst2018',
       'Net_International_Migration_2010_2019', 'TotalPopEst2019',
       'TotalPopEst2012', 'NetMigration1019',
       'Net_International_Migration_Rate_2010_2019', 'NaturalChangeRate1019',
       'NetMigrationRate1019', 'PopChangeRate1019', 'TotalPopEst2014',
       'TotalPopEst2013', 'TotalPopEstBase2010', 'TotalPopEst2011',
       'TotalPopEst2010', 'ESTIMATESBASE2020', 'POPESTIMATE2020',
       'NaturalChg2020_2021', 'Net_InterMigration_2020_2021',
       'Net_Migration_2020_2021']

outlier_info=[]

for column in cols:
    q1=people[column].quantile(0.25)
    q3=people[column].quantile(0.75)
    iqr=q3-q1 
    ul= q3+1.5*iqr 
    ll=q1-1.5*iqr
    outlier=people[(people[column] <ll) | (people[column] >ul)]
    outlier_info.append({'Feature': column, 'No. of Outliers': outlier.shape[0]})

outlier_df = pd.DataFrame(outlier_info)
outlier_df['Outlier Proportion']=outlier_df['No. of Outliers']*100/people.shape[0]
outlier_df
# Out:
#                              Feature  No. of Outliers  Outlier Proportion
# 0          Pop_change_Rate_2020_2021              182            5.550473
# 1                    POPESTIMATE2021              464           14.150656
# 2       Net_Migration_Rate_2020_2021              178            5.428484
# 3      Natural_Change_Rate_2020_2021               83            2.531260
# 4   Net_InterMigrationRate_2020_2021              264            8.051235
# ..                               ...              ...                 ...
# 86                 ESTIMATESBASE2020              458           13.967673
# 87                   POPESTIMATE2020              459           13.998170
# 88               NaturalChg2020_2021              620           18.908204
# 89      Net_InterMigration_2020_2021              516           15.736505
# 90           Net_Migration_2020_2021              585           17.840805
#
# [91 rows x 3 columns]

# %%
print(max(outlier_df['Outlier Proportion']))
# Out:
# 21.286977737114974

# %%
outlier_desc=outlier_df.sort_values(by='Outlier Proportion', ascending=False)[['Feature', 'Outlier Proportion']]
print(outlier_desc)
# Out:
#                     Feature  Outlier Proportion
# 76         NetMigration1019           21.286978
# 88      NaturalChg2020_2021           18.908204
# 90  Net_Migration_2020_2021           17.840805
# 23  AsianNonHispanicNum2020           17.230863
# 53       ForeignBornAsiaNum           16.986886
# ..                      ...                 ...
# 38         HH65PlusAlonePct            2.500762
# 33        Ed3SomeCollegePct            2.439768
# 31         Ed1LessThanHSPct            2.256786
# 34        Ed4AssocDegreePct            1.768832
# 32      Ed2HSDiplomaOnlyPct            0.731930
#
# [91 rows x 2 columns]

# %%
outlier_desc['Feature'].values
# Out:
# array(['NetMigration1019', 'NaturalChg2020_2021',
#        'Net_Migration_2020_2021', 'AsianNonHispanicNum2020',
#        'ForeignBornAsiaNum', 'ForeignBornAfricaNum', 'NaturalChange1019',
#        'NonEnglishHHNum', 'Net_International_Migration_2010_2019',
#        'ForeignBornCaribNum', 'Ed5CollegePlusNum', 'ForeignBornNum',
#        'Net_InterMigration_2020_2021', 'HispanicNum2020',
#        'ForeignBornEuropeNum', 'ForeignBornCentralSouthAmNum',
#        'NativeAmericanNonHispanicNum2020', 'MultipleRaceNum2020',
#        'PopDensity2020', 'BlackNonHispanicNum2020', 'ForeignBornMexNum',
#        'Under18Num2020', 'TotalHH', 'NativeAmericanNonHispanicPct2020',
#        'TotalOccHU', 'TotalPopEst2018', 'POPESTIMATE2021',
#        'TotalPopEst2019', 'TotalPop25Plus', 'TotalPopACS',
#        'POPESTIMATE2020', 'ESTIMATESBASE2020', 'TotalPop2020',
#        'TotalPopEst2017', 'Ed3SomeCollegeNum', 'FemaleHHNum',
#        'TotalPopEst2016', 'TotalPopEst2015', 'OwnHomeNum',
# ...

# %%
#drop rows containing Null values 
before=people.shape[0]
cols= ['Pop_change_Rate_2020_2021', 'POPESTIMATE2021',
       'Net_Migration_Rate_2020_2021', 'Natural_Change_Rate_2020_2021',
       'Net_InterMigrationRate_2020_2021', 'PopChangeRate1020',
       'PopDensity2020', 'Under18Pct2020', 'Age65AndOlderPct2020',
       'WhiteNonHispanicPct2020', 'BlackNonHispanicPct2020',
       'AsianNonHispanicPct2020', 'NativeAmericanNonHispanicPct2020',
       'HispanicPct2020', 'MultipleRacePct2020',
       'NonHispWhitePopChangeRate1020', 'NonHispBlackPopChangeRate1020',
       'NonHispAsianPopChangeRate1020', 'NonHispNatAmerPopChangeRate1020',
       'HispanicPopChangeRate1020', 'MultipleRacePopChangeRate1020',
       'WhiteNonHispanicNum2020', 'BlackNonHispanicNum2020',
       'AsianNonHispanicNum2020', 'NativeAmericanNonHispanicNum2020',
       'HispanicNum2020', 'MultipleRaceNum2020', 'ForeignBornPct',
       'ForeignBornEuropePct', 'ForeignBornMexPct', 'NonEnglishHHPct',
       'Ed1LessThanHSPct', 'Ed2HSDiplomaOnlyPct', 'Ed3SomeCollegePct',
       'Ed4AssocDegreePct', 'Ed5CollegePlusPct', 'AvgHHSize', 'FemaleHHPct',
       'HH65PlusAlonePct', 'OwnHomePct', 'Ed3SomeCollegeNum',
       'Ed2HSDiplomaOnlyNum', 'Ed1LessThanHSNum', 'TotalPopACS',
       'ForeignBornNum', 'TotalPop25Plus', 'ForeignBornEuropeNum',
       'ForeignBornCaribNum', 'ForeignBornMexNum', 'Ed5CollegePlusNum',
       'HH65PlusAloneNum', 'Ed4AssocDegreeNum', 'ForeignBornAfricaNum',
       'ForeignBornAsiaNum', 'NonEnglishHHNum', 'OwnHomeNum', 'FemaleHHNum',
       'TotalHH', 'ForeignBornCentralSouthAmPct',
       'ForeignBornCentralSouthAmNum', 'ForeignBornCaribPct',
       'ForeignBornAsiaPct', 'TotalOccHU', 'ForeignBornAfricaPct',
       'Age65AndOlderNum2020', 'Under18Num2020', 'LandAreaSQMiles2020',
       'TotalPop2020', 'NaturalChange1019', 'TotalPopEst2015',
       'TotalPopEst2016', 'TotalPopEst2017', 'TotalPopEst2018',
       'Net_International_Migration_2010_2019', 'TotalPopEst2019',
       'TotalPopEst2012', 'NetMigration1019',
       'Net_International_Migration_Rate_2010_2019', 'NaturalChangeRate1019',
       'NetMigrationRate1019', 'PopChangeRate1019', 'TotalPopEst2014',
       'TotalPopEst2013', 'TotalPopEstBase2010', 'TotalPopEst2011',
       'TotalPopEst2010', 'ESTIMATESBASE2020', 'POPESTIMATE2020',
       'NaturalChg2020_2021', 'Net_InterMigration_2020_2021',
       'Net_Migration_2020_2021']

for column in cols:  
    people = people.dropna(subset=[column])

after=people.shape[0]
print('Number of rows with null values removed:', before-after)
# Out:
# Number of rows with null values removed: 141

# %%
people.reset_index(drop=True, inplace=True)
people.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3138 entries, 0 to 3137
# Data columns (total 93 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   State                                       3138 non-null   object
#  1   County                                      3138 non-null   object
#  2   Pop_change_Rate_2020_2021                   3138 non-null   float64
#  3   POPESTIMATE2021                             3138 non-null   float64
#  4   Net_Migration_Rate_2020_2021                3138 non-null   float64
#  5   Natural_Change_Rate_2020_2021               3138 non-null   float64
#  6   Net_InterMigrationRate_2020_2021            3138 non-null   float64
#  7   PopChangeRate1020                           3138 non-null   float64
#  8   PopDensity2020                              3138 non-null   float64
# ...

# %%
people
# Out:
#      State      County  Pop_change_Rate_2020_2021  POPESTIMATE2021  \
# 0       AL     Alabama                   0.299992        5039877.0
# 1       AL     Autauga                   0.370263          59095.0
# 2       AL     Baldwin                   2.639616         239294.0
# 3       AL     Barbour                  -0.857824          24964.0
# 4       AL        Bibb                   1.142960          22477.0
# ...    ...         ...                        ...              ...
# 3133    WY  Sweetwater                  -1.290384          41614.0
# 3134    WY       Teton                   0.976571          23575.0
# 3135    WY       Uinta                   0.949073          20635.0
# 3136    WY    Washakie                   0.613737           7705.0
# 3137    WY      Weston                  -0.939932           6745.0
#
#       Net_Migration_Rate_2020_2021  Natural_Change_Rate_2020_2021  \
# 0                         0.470108                      -0.170116
# ...

# %%
sns.heatmap(people.isnull(), cbar=False)
plt.show()

# %%
#jobs.to_excel('RuralAreafinal.xlsx', sheet_name='Jobs')

# %%
file_path = 'D:\OneDrive\Documents\Course\Imarticus Learning\Tableau\Data\RuralAreafinal.xlsx'

# Load the existing Excel file
with pd.ExcelWriter(file_path, engine='openpyxl', mode='a') as writer:
    # Create a new sheet named 'NewSheet'
    people.to_excel(writer, sheet_name='People', index=False)

print("Data exported successfully!")
# Out:
# Data exported successfully!
